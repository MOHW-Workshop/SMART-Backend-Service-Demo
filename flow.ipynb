        "kid": "5Vx8IQ3h6zmg9WReJEnx_eraKSuFqB65IETs8FYt3LI",
        "alg": "RS256",
    }
)

# %%
import json

# Public key with kid and alg
public_key = key.as_dict(private=False)
public_key["kid"] = key.thumbprint()
public_key["alg"] = "RS256"
print(json.dumps(public_key))
# Out:
# {"n": "r-q3taj23oAcbNCOr2y_c_wVPbGhmY_tI4PQIQQnNn-9BUhv-uGC9rwfDjc-Xt1IfZsPYSYnEanWy7kHFoGD8ZQNzB3zvyeQFp8X5vGi7k8tGggQJrCanwd52m93xArfy343Hoj9yp6WcVjoYYZLHG0u-j2jYjT-IgHJrQQj8F9D-7Tb06lfIYt_QrKo_3N7pkKunBGhbsW1naakCXeNHbBcG0josAbfYJu0j1YzRw-WOrQCWwDFOtmUoj4rYcjBeO8lobvebyW8Xk4smml5fItklEYgHhFAkQkflT1-aYW1igySCRh_sPuE0Pxm4OX4fzvO0U4LWKTHds0EyrMRAQ", "e": "AQAB", "kty": "RSA", "kid": "5Vx8IQ3h6zmg9WReJEnx_eraKSuFqB65IETs8FYt3LI", "alg": "RS256"}

# %%
# Private key with kid and alg
private_key = key.as_dict()
private_key["kid"] = key.thumbprint()
private_key["alg"] = "RS256"
print(json.dumps(private_key))
# Out:
# {"n": "r-q3taj23oAcbNCOr2y_c_wVPbGhmY_tI4PQIQQnNn-9BUhv-uGC9rwfDjc-Xt1IfZsPYSYnEanWy7kHFoGD8ZQNzB3zvyeQFp8X5vGi7k8tGggQJrCanwd52m93xArfy343Hoj9yp6WcVjoYYZLHG0u-j2jYjT-IgHJrQQj8F9D-7Tb06lfIYt_QrKo_3N7pkKunBGhbsW1naakCXeNHbBcG0josAbfYJu0j1YzRw-WOrQCWwDFOtmUoj4rYcjBeO8lobvebyW8Xk4smml5fItklEYgHhFAkQkflT1-aYW1igySCRh_sPuE0Pxm4OX4fzvO0U4LWKTHds0EyrMRAQ", "e": "AQAB", "d": "AmCQ8yiKmnE4j5cdtn8Qqex79Dxs13p-hcesOG8j7v2miFof3E_0NusRBVIodVL1VjNI--tiQg8iKDo7AmKQJKa6S6uNFzO4_zhO9wvg4faVd3Fx-Xn3YYJkQhsfUidas_7jyF0vdJpaf89VkkpJPlGSol9AYtKwgKkkklqiuzeQO3QQzAPbVYSqlqBC6xYtTTfiDiEH1dmBieaPVc1VsKPAP-RMSjIVMxbeN1AXrDNbq9Y1IIBEf4qWErJPLyuXloky0XUXPjraK11IjaTvUzpl8VKLtuFL6I10bCTevkSuvnEP6Bc5I7UOKqeIcKa4Hs02OpmloGpoZyGbMTU9mQ", "p": "13EddmmUzqIE8e3wMe1zkVg3Hnr_VzBZnyRg4PD0jTGHmKozWcNf4GzANKJYbbX66ArqJ2yoTTEorTinc0j05d5WhvXWu6wmwq8jK918SxVn6YYMG6SezGGQn0YHRkZLWbgfSvM04HmSs1k-Kxde7idDthKDu6V4uEeu2VMBTrM", "q": "0QjB1HJJuFJgZHYLmyFR7K6blsKpG9lwwIEeF54rDQ_HfcHA6BaqTyN26esc1-ZDU1K7O8vjV-kj3rM7DTtmntYGpoxRLj7M
# ...

# %% [markdown]
# ### 2. Retrieve .well-known/smart-configuration

# %%
import requests

FHIR_BASE_URL = "https://gw.interop.community/smartR4/data"
Client_ID = "ecd805fd-211a-4586-ad03-7c866bc837d7"

# %%
resp = requests.get(f"{FHIR_BASE_URL}/.well-known/smart-configuration", verify=False)
smart_configuration = resp.json()
smart_configuration
# Out:
# d:\Codes\FHIR\SMART Backend Service Demo\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gw.interop.community'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'authorization_endpoint': 'https://iol2auth.interop.community/authorize',
#  'token_endpoint': 'https://iol2auth.interop.community/token',
#  'token_endpoint_auth_methods': None,
#  'registration_endpoint': 'https://iol2auth.interop.community/register',
#  'scopes_supported': ['smart/orchestrate_launch',
#   'launch',
#   'openid',
#   'profile',
#   'user/*.*',
#   'user/*.read',
#   'user/*.write',
#   'user/AdverseReaction.read',
#   'user/AdverseReaction.write',
#   'user/Alert.read',
#   'user/Alert.write',
#   'user/Condition.read',
#   'user/Condition.write',
#   'user/Encounter.read',
#   'user/Encounter.write',
# ...

# %% [markdown]
# ### 3. Create Client Assertion Token

# %%
from joserfc import jwt
import datetime

# %%
header = {
    "alg": "RS256",
    "typ": "JWT",
    "kid": key.thumbprint(),
}

now = datetime.datetime.now(datetime.UTC)
claims = {
    "iss": Client_ID,
    "sub": Client_ID,
    "aud": smart_configuration['token_endpoint'],
    "exp": now + datetime.timedelta(minutes=5),
    "jti": "random-non-reusable-jwt-id-123"
}

client_assertion = jwt.encode(header, claims, key, )
print(client_assertion)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImtpZCI6IjVWeDhJUTNoNnptZzlXUmVKRW54X2VyYUtTdUZxQjY1SUVUczhGWXQzTEkifQ..bDVcZT4RORrdXIQTS8A_CVR2jQ_ah7KUpm2fcle4uBA9c_vMSY5py6IRaLKBPky994xVt0_nP80CjNMsv6s3Bq1hiHVipEdh08iu9wPQjsFb6_zHhDrx1KHyh5ApQu82Xyu9VU3kt8Ct9IE2NZKJqjKuZ9AA6BGR3jW0a-eXOIDwdJ5WkYuNsHkZu2vceIXUBseoPm8R1gkMITv2qh2p8pI_PJVdcesLv5nShZt6xVh3YYPlSahoIoHDCX-Ro3mwBjhrtkWQ4HcO4D9JwRkWZLd8U7A0qk9EXjgTJU3bYgctis5OgfD89sB9DBPV293T3o6tcOeIzoSxfuxex0c6mg

# %% [markdown]
# ### 4. Retrieve Access Token

# %%
resp = requests.post(
    smart_configuration['token_endpoint'],
    data={
        "grant_type": "client_credentials",
        "client_assertion_type": "urn:ietf:params:oauth:client-assertion-type:jwt-bearer",
        "client_assertion": client_assertion,
        # "scope": "system/*.*"
        "scope":"openid system/*.* launch launch/patient user/*.* patient/*.*"
    },
    headers={"Content-Type": "application/x-www-form-urlencoded"},
    verify=False
)

token = resp.json().get("access_token")

resp.json()
# Out:
# d:\Codes\FHIR\SMART Backend Service Demo\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'iol2auth.interop.community'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...

# %% [markdown]
# ### 5. Access FHIR Resource

# %%
resp = requests.get(
    f"{FHIR_BASE_URL}/Patient/141",
    headers={
        "Authorization": f"Bearer {token}"
    },
    verify=False
)
resp.json()
# Out:
# d:\Codes\FHIR\SMART Backend Service Demo\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gw.interop.community'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File d:\Codes\FHIR\SMART Backend Service Demo\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
# ...

# %%
# Out:
# notebook controller is DISPOSED.
#
# 如需詳細資料，請檢視 Jupyter <a href='command:jupyter.viewOutput'>記錄</a>。
